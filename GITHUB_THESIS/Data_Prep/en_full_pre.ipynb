# %%
import re
import pandas as pd
from tqdm import tqdm

# %%
df = pd.read_csv('Dataset_en.tsv', sep='\t')

#filter appropriate years
df = df[(df['year'] >= 1600) & (df['year'] <= 1980)]

# %%
#make the smell source lemma column a list of strings
df['source_list'] = df['Smell_Source_lemma'].str.split('|')
print(1)
df = df[df['source_list'].apply(lambda x: isinstance(x, list))]
print(2)
df = df[df['source_list'].apply(lambda x: all(isinstance(word, str) for word in x))]
print(3)
df['source_list'] = df['source_list'].apply(lambda x: [word.strip() for word in x])
print(4)
df.head()
# Out:
# 1
# 2
# 3
# 4
#    Unnamed: 0 Lang  year            Smell_Source_lemma Quality_lemma  \
# 0           0   en  1940             hydrochloric acid           NaN
# 1           1   en  1863              pepsine | motion           NaN
# 2           2   en  1894  riolous | perfon | principle           NaN
# 3           3   en  1959                           lov           NaN
# 4           4   en  1893             hawthorn | manual           NaN
#
#                                       Sentence_lemma            Corpus  \
# 0  stomach normally acid reaction , putrefaction ...  medical-heritage
# 1  357 \ solid matter copious , pale , fetid , co...  medical-heritage
# 2  thefe rather prove vifibi - lity animal vapour...  medical-heritage
# 3  - ' cause great deal disturbance supply give r...  medical-heritage
# 4  268 .312 manual bagteriolooy odour hawthorn , ...  medical-heritage
#
#                  Smell_Source Quality  \
# 0           Hydrochloric acid     NaN
# 1         Pepsine|the motions     NaN
# 2  riolous|Perfons|Principles     NaN
# 3                         lov     NaN
# 4             Hawthorn|MANUAL     NaN
#
#                                             Sentence  \
# 0  The stomach normally has an acid reaction , bu...
# 1  357 T \ here the solid matter is copious , pal...
# 2  But thefe rather prove the Vifibi - lity of th...
# 3  T - ' is caused a great deal of disturbance to...
# 4  268 .312 A MANUAL OF BAGTERIOLOOY the odour of...
#
#                     source_list
# 0           [hydrochloric acid]
# 1             [pepsine, motion]
# 2  [riolous, perfon, principle]
# 3                         [lov]
# 4            [hawthorn, manual]

# %%
def preprocess_text(sentence):
    # Remove numbers, abbreviations, and unknown/special characters
    # Removes numbers
    sentence = re.sub(r'\d+', '', sentence)
    # Removes single characters and special characters
    sentence = re.sub(r'\W', ' ', sentence)
    # Removes single characters from the start
    sentence = re.sub(r'\^[a-zA-Z]\s+', ' ', sentence) 
    # Substitutes multiple spaces with single space
    sentence = re.sub(r'\s+', ' ', sentence, flags=re.I)
    # Removes prefixed 'b'
    sentence = re.sub(r'^b\s+', '', sentence)
    # Converts to lower case
    sentence = sentence.lower()
    return sentence

# %%
df['pre_text'] = df['Sentence'].apply(preprocess_text)

# %%
df[['pre_text', 'Sentence', 'year', 'Smell_Source', 'source_list']]
# Out:
#                                                   pre_text  \
# 0        the stomach normally has an acid reaction but ...
# 1         t here the solid matter is copious pale and f...
# 2        but thefe rather prove the vifibi lity of the ...
# 3        t is caused a great deal of disturbance to the...
# 4         a manual of bagteriolooy the odour of hawthor...
# ...                                                    ...
# 1360685  then pendulous like amethysts and rubies purpl...
# 1360686  no doubt in time he would prefer it but he wis...
# 1360688  then at an odor stealing inward through the ke...
# 1360691  thereafter the giantesses headed by kuntî said...
# 1360692  thereafter the giantesses headed by kuntî said...
#
#                                                   Sentence  year  \
# 0        The stomach normally has an acid reaction , bu...  1940
# 1        357 T \ here the solid matter is copious , pal...  1863
# 2        But thefe rather prove the Vifibi - lity of th...  1894
# 3        T - ' is caused a great deal of disturbance to...  1959
# 4        268 .312 A MANUAL OF BAGTERIOLOOY the odour of...  1893
# ...                                                    ...   ...
# 1360685  Then pendulous , like amethysts And rubies , p...  1917
# 1360686  No doubt in time he would prefer it ; but he w...  1892
# 1360688  Then , at an odor stealing inward through the ...  1923
# 1360691  Thereafter the giantesses headed by Kuntî said...  1884
# 1360692  Thereafter the giantesses headed by Kuntî said...  1884
#
#                                               Smell_Source  \
# 0                                        Hydrochloric acid
# 1                                      Pepsine|the motions
# 2                               riolous|Perfons|Principles
# 3                                                      lov
# 4                                          Hawthorn|MANUAL
# ...                                                    ...
# 1360685             goldenrods|blossoms of the haw|calmias
# 1360686                             bygone cabbage|kindred
# 1360688                                           Ether|of
# 1360691  Garland|Flower|Powder|Cloth|Ointment|Incense|J...
# 1360692  Garland|Flower|Powder|Cloth|Ointment|Incense|J...
#
#                                                source_list
# 0                                      [hydrochloric acid]
# 1                                        [pepsine, motion]
# 2                             [riolous, perfon, principle]
# 3                                                    [lov]
# 4                                       [hawthorn, manual]
# ...                                                    ...
# 1360685                  [goldenrod, blossom haw, calmias]
# 1360686                           [bygone cabbage, kindre]
# 1360688                                          [ether, ]
# 1360691  [garland, flower, powder, cloth, ointment, inc...
# 1360692  [garland, flower, powder, cloth, ointment, inc...
#
# [936309 rows x 5 columns]

# %%
def filter_df_by_sources(source_lists, match_sources):
    match_sources_set = set(match_sources)  # Convert list to set for faster operations
    # Check if any item in the row's source list is in the match sources
    return [any(item in match_sources_set for item in source_list) for source_list in source_lists]

bloemen = ['flower', 'flowers']
df['bloem'] = filter_df_by_sources(df['source_list'], bloemen)
flower = df[df['bloem']]
flower
# Out:
#          Unnamed: 0 Lang  year  \
# 72               72   en  1927
# 73               73   en  1927
# 74               74   en  1927
# 75               75   en  1927
# 81               81   en  1855
# ...             ...  ...   ...
# 1360656       80502   en  1919
# 1360661       80507   en  1924
# 1360667       80513   en  1919
# 1360691       80537   en  1884
# 1360692       80538   en  1884
#
#                                         Smell_Source_lemma  \
# 72                inflammable air | fcecal matter | flower
# 73                inflammable air | fcecal matter | flower
# 74                inflammable air | fcecal matter | flower
# 75                inflammable air | fcecal matter | flower
# 81                                                  flower
# ...                                                    ...
# 1360656                                             flower
# 1360661                               flower | shiraz wine
# 1360667                                           flower |
# 1360691  garland | flower | powder | cloth | ointment |...
# 1360692  garland | flower | powder | cloth | ointment |...
#
#                                              Quality_lemma  \
# 72       dangerous | unnatural | agreeable | noisome | ...
# 73       dangerous | unnatural | agreeable | noisome | ...
# 74       dangerous | unnatural | agreeable | noisome | ...
# 75       dangerous | unnatural | agreeable | noisome | ...
# 81                                                     NaN
# ...                                                    ...
# 1360656                          odorous | spiky | miasmic
# 1360661                          scented | flower | golden
# 1360667                                  lovely | fragrant
# 1360691  lotus - scented | vârshika - scented | - scent...
# 1360692  lotus - scented | vârshika - scented | - scent...
#
#                                             Sentence_lemma            Corpus  \
# 72       â   head flower send we contain twenty - thr...  medical-heritage
# 73       month .after sea , itlie bung take cask , send...  medical-heritage
# 74       perfectly healthy date digedive organ , probab...  medical-heritage
# 75       ) strasburg turpentine .this resin geneâ ¬ ral...  medical-heritage
# 81       western side strait , â   vegetation stunt ,...  medical-heritage
# ...                                                    ...               ...
# 1360656  feel journey , back security coast ragged unio...        wikisource
# 1360661  porter pass singly twos three .the last tall n...        wikisource
# 1360667               , value married success happiness...        wikisource
# 1360691  thereafter giantess head kuntî say unto lord :...        wikisource
# 1360692  thereafter giantess head kuntî say unto lord :...        wikisource
#
#                                               Smell_Source  \
# 72                inflammable air|the fcecal matter|Flower
# 73                inflammable air|the fcecal matter|Flower
# 74                inflammable air|the fcecal matter|Flower
# 75                inflammable air|the fcecal matter|Flower
# 81                                                  Flower
# ...                                                    ...
# 1360656                                   the very flowers
# 1360661                                 Flower|Shiraz wine
# 1360667                                        Flower|they
# 1360691  Garland|Flower|Powder|Cloth|Ointment|Incense|J...
# 1360692  Garland|Flower|Powder|Cloth|Ointment|Incense|J...
#
#                                                    Quality  \
# 72       dangerous|unnatural|more agreeable|noisome|var...
# 73       dangerous|unnatural|more agreeable|noisome|var...
# 74       dangerous|unnatural|more agreeable|noisome|var...
# 75       dangerous|unnatural|more agreeable|noisome|var...
# 81                                                     NaN
# ...                                                    ...
# 1360656                              odorous|spiky|miasmic
# 1360661                              scented|flower|golden
# 1360667                                    lovely|fragrant
# 1360691  lotus -  scented|Vârshika -  scented|-  scente...
# 1360692  lotus -  scented|Vârshika -  scented|-  scente...
#
#                                                   Sentence  \
# 72       â   The head of flowers sent us contained tw...
# 73       In about a month .after it has been at sea , w...
# 74       In a perfectly healthy date of the digedive or...
# 75       ) Strasburg Turpentine .This resin is geneÂ ¬ ...
# 81       On the western side of the Straits , â   veg...
# ...                                                    ...
# 1360656  But what they had felt on that journey , back ...
# 1360661  The porters passed in singly and by twos and t...
# 1360667  " Don ' t do that , as you value your married ...
# 1360691  Thereafter the giantesses headed by Kuntî said...
# 1360692  Thereafter the giantesses headed by Kuntî said...
#
#                                                source_list  \
# 72                [inflammable air, fcecal matter, flower]
# 73                [inflammable air, fcecal matter, flower]
# 74                [inflammable air, fcecal matter, flower]
# 75                [inflammable air, fcecal matter, flower]
# 81                                                [flower]
# ...                                                    ...
# 1360656                                           [flower]
# 1360661                              [flower, shiraz wine]
# 1360667                                         [flower, ]
# 1360691  [garland, flower, powder, cloth, ointment, inc...
# 1360692  [garland, flower, powder, cloth, ointment, inc...
#
#                                                   pre_text  bloem
# 72       â the head of flowers sent us contained twenty...   True
# 73       in about a month after it has been at sea when...   True
# 74       in a perfectly healthy date of the digedive or...   True
# 75        strasburg turpentine this resin is geneâ rall...   True
# 81       on the western side of the straits â vegetatio...   True
# ...                                                    ...    ...
# 1360656  but what they had felt on that journey back to...   True
# 1360661  the porters passed in singly and by twos and t...   True
# 1360667   don t do that as you value your married succe...   True
# 1360691  thereafter the giantesses headed by kuntî said...   True
# 1360692  thereafter the giantesses headed by kuntî said...   True
#
# [46236 rows x 13 columns]

# %%
import pandas as pd

random_rows = flower.sample(n=3)

# Print the entire sentence for each randomly selected row
for index, row in random_rows.iterrows():
    print(row['Sentence'])
# Out:
# â   42 .back , with acute angular margins , pale green , sometimes rugged , with rust - coloured dots , sometimes without , and quite smooth , from an inch and a half to six inches in length ; scape round , slender , from a foot to two feet in length ; flowers sweet - smelling , elegantly variegated with purple , violet , yel - low , and red ; petals four .â   Native of the woods in Jamaica and Hispaniola .
# Sympathy Must call her in Love ' s name ! and then , I know , She rises up , and brightens , as she should , And lights her smile for comfort , and is slow In nothing of high -  hearted fortitude .To smell this flower , come near it : such can grow In that sole garden where Christ ' s brow dropped blood .  66 SONNETS .
# Yet let us take courage , illustrious nobles and chieftains , true friends and loyal subjects , — let us aspire to that heaven , where all is 109 Aztec Civilisation Various musical instruments were placed on the top of the tower , and the sound of them , accompanied by the ringing of a sonorous metal struck by a mallet , summoned the worshippers to prayers at regular seasons .1 No image was allowed in the edifice , as unsuited to the " invisible God " ; and the people were expressly prohibited from profaning the altars with blood , or any other sacrifice than that of the perfume of flowers and sweet -  scented gums .The remainder of his days was chiefly spent in his delicious solitudes of Tezcotzinco , where he devoted himself to astronomical and , probably , astrological studies , and to meditation on his immortal destiny , — giving utterance to his feelings in songs , or rather hymns , of much solemnity and pathos .

# %%
flower[['pre_text', 'Sentence', 'year', 'Smell_Source', 'source_list']]
# Out:
#                                                   pre_text  \
# 72       â the head of flowers sent us contained twenty...
# 73       in about a month after it has been at sea when...
# 74       in a perfectly healthy date of the digedive or...
# 75        strasburg turpentine this resin is geneâ rall...
# 81       on the western side of the straits â vegetatio...
# ...                                                    ...
# 1360656  but what they had felt on that journey back to...
# 1360661  the porters passed in singly and by twos and t...
# 1360667   don t do that as you value your married succe...
# 1360691  thereafter the giantesses headed by kuntî said...
# 1360692  thereafter the giantesses headed by kuntî said...
#
#                                                   Sentence  year  \
# 72       â   The head of flowers sent us contained tw...  1927
# 73       In about a month .after it has been at sea , w...  1927
# 74       In a perfectly healthy date of the digedive or...  1927
# 75       ) Strasburg Turpentine .This resin is geneÂ ¬ ...  1927
# 81       On the western side of the Straits , â   veg...  1855
# ...                                                    ...   ...
# 1360656  But what they had felt on that journey , back ...  1919
# 1360661  The porters passed in singly and by twos and t...  1924
# 1360667  " Don ' t do that , as you value your married ...  1919
# 1360691  Thereafter the giantesses headed by Kuntî said...  1884
# 1360692  Thereafter the giantesses headed by Kuntî said...  1884
#
#                                               Smell_Source  \
# 72                inflammable air|the fcecal matter|Flower
# 73                inflammable air|the fcecal matter|Flower
# 74                inflammable air|the fcecal matter|Flower
# 75                inflammable air|the fcecal matter|Flower
# 81                                                  Flower
# ...                                                    ...
# 1360656                                   the very flowers
# 1360661                                 Flower|Shiraz wine
# 1360667                                        Flower|they
# 1360691  Garland|Flower|Powder|Cloth|Ointment|Incense|J...
# 1360692  Garland|Flower|Powder|Cloth|Ointment|Incense|J...
#
#                                                source_list
# 72                [inflammable air, fcecal matter, flower]
# 73                [inflammable air, fcecal matter, flower]
# 74                [inflammable air, fcecal matter, flower]
# 75                [inflammable air, fcecal matter, flower]
# 81                                                [flower]
# ...                                                    ...
# 1360656                                           [flower]
# 1360661                              [flower, shiraz wine]
# 1360667                                         [flower, ]
# 1360691  [garland, flower, powder, cloth, ointment, inc...
# 1360692  [garland, flower, powder, cloth, ointment, inc...
#
# [46236 rows x 5 columns]

# %%
flower.to_csv('flowers.csv')
